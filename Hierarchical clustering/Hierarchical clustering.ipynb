# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=pd.read_csv('Mall_Customers.csv')

# %%
X=dataset.iloc[:,[3,4]].values

# %%
import scipy.cluster.hierarchy as sch

# %%
#finding optimum no of cluster...
dangogram=sch.dendrogram(sch.linkage(X,method='ward'))
plt.title('Dendogram')
plt.xlabel("Clustering")
plt.ylabel("euclidien distance")
plt.tight_layout()

# %%
#here we get optimum no of cluster=5.

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
cluster=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')

# %%
y_hc=cluster.fit_predict(X)

# %%
#visualization:

# %%
plt.scatter(X[y_hc==0,0],X[y_hc==0,1],s=50,c='red',label='Cluster -1')
plt.scatter(X[y_hc==1,0],X[y_hc==1,1],s=50,c='blue',label='Cluster 2')
plt.scatter(X[y_hc==2,0],X[y_hc==2,1],s=50,c='green',label='Cluster 3')
plt.scatter(X[y_hc==3,0],X[y_hc==3,1],s=50,c='cyan',label='Cluster 4')

plt.scatter(X[y_hc==4,0],X[y_hc==4,1],s=50,c='yellow',label='Cluster 5')

plt.title('5 cluster ')
plt.xlabel('Annual income')
plt.ylabel('Spending money')
plt.legend(loc=0)
